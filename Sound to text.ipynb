# %%
#pip install SpeechRecognition moviepy
#pip install pafy
#pip install --upgrade youtube_dl

import speech_recognition as sr
import moviepy.editor as mp

# Manipulación de Audio 
from pydub import AudioSegment
from pydub.silence import split_on_silence
from pytube import YouTube

# Otras librerías
import os, shutil

# %%
class SoundToText:
    """
    Define a file with a video format.
    """
    def __init__(self, video_file):
        self.video_file = video_file
        self.current_directory = os.getcwd()
        self.video_description = ""
        self.current_folder = self.current_directory + "\\Converted results"
        self.converted_audio = self.current_folder + "\\"+ "Converted_audio.wav"
    
    """
    Download a video from YouTube.
    """
    def download_from_youtube(self):
        yt_file = YouTube(self.video_file)
        self.video_description = yt_file.description
        
        yt_file = yt_file.streams.get_highest_resolution()
        if not os.path.exists(self.current_folder):
            os.makedirs(self.current_folder)
        yt_file.download(self.current_folder)
     
    """
    Converts a video to audio file.
    """
    # It will write the audio in converted_audio.wav file.
    def convert_to_audio(self):
        for file in os.listdir(self.current_folder):
            file = self.current_folder + "\\" + file
            if file.endswith(".mp4"):
                raw_string = r"{}".format(file)
                raw_audio = r"{}".format( self.converted_audio)
                
                clip = mp.VideoFileClip(raw_string)#.subclip(10, 100)
                clip.audio.write_audiofile(raw_audio)
                print("Finished the convertion into audio...")
                   
    # It will read audio file
    def read_audio_file(self):
        audio = sr.AudioFile(self.converted_audio)
        print("Audio file readed...")
     
    # Define a function to normalize a chunk to a target amplitude.
    def match_target_amplitude(self, aChunk, target_dBFS):
        change_in_dBFS = target_dBFS - aChunk.dBFS
        return aChunk.apply_gain(change_in_dBFS)

    def create_audio_chunks(self, audio):
    # split audio sound where silence is 700 miliseconds or more and get chunks
        chunks = split_on_silence(audio,
            # experiment with this value for your target audio file
            min_silence_len = 500,
            # adjust this per requirement
            silence_thresh = -40,
            # keep the silence for 1 second, adjustable as well
            #keep_silence=100,
        )
        return chunks

    # Splits the audio file into chunks
    # and applies speech recognition
    def get_audio_transcription(self):
        r = sr.Recognizer()
        
        path = self.converted_audio # TODO change name
        # open the audio file using pydub
        folder_name = path.replace("wav","")
    
        fh = open(folder_name + "txt", "w+") 
        audio = AudioSegment.from_wav(path)  
    
        # Create chunks of audio
        chunks = self.create_audio_chunks(audio)
    
        # Create a directory to store the audio chunks
        if not os.path.isdir(folder_name):
            os.mkdir(folder_name)
        whole_text = ""

        # process each chunk 
        for i, audio_chunk in enumerate(chunks, start=0):
            silence_chunk = AudioSegment.silent(duration=500)
            
             # Add the padding chunk to beginning and end of the entire chunk.
            audio_chunk = silence_chunk + audio_chunk + silence_chunk
            
            # export audio chunk and save it in
            # the `folder_name` directory.
            chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
            
            # Normalize the entire chunk.
            normalized_chunk = self.match_target_amplitude(audio_chunk, -20.0)
            
            normalized_chunk.export(chunk_filename, bitrate = "192k", format="wav")
            
            # recognize the chunk
            with sr.AudioFile(chunk_filename) as source:
                # Now from here we convert audio into text
                r.energy_threshold = 300
                r.adjust_for_ambient_noise(source, duration=0.5)
                
                audio_file = r.record(source)
            
                # try converting it to text
                try:  
                    text = r.recognize_google(audio_file, language='es-MX') 
                except sr.UnknownValueError as e:
                    print("Error:", str(e))
                else:
                    text = f"{text} "
                    #print(" -- :", text)
                    whole_text += text
                    
        # If exists a description, it will be added in whole_text
        video_description = "\nDescripción del Video: \n" + str(self.video_description)
        whole_text += video_description
        
        #word = "ingredientes" # TODO cambiar palabras 
        #if not word in whole_text:
        #    print("No es video-receta!")
        #    return
        
        # return the text for all chunks detected
        fh.write(whole_text + "\n") 
        return print("\nFull text:", whole_text)
    
    def convert_video_to_audio(self):
        if "youtube" in self.video_file: #optimizar en frontend
            self.download_from_youtube()
            self.convert_to_audio()
            self.read_audio_file()
            self.get_audio_transcription()
        else:
            self.read_audio_file()
            self.get_audio_transcription()
        #self.remove_filed() #TODO error => no elimina mp4
            
    def remove_filed(self):
        for filename in os.listdir(self.current_folder):
            file_path = os.path.join(self.current_folder, filename)
            try:
                if os.path.isfile(file_path) or os.path.islink(file_path):
                    os.unlink(file_path)
                elif os.path.isdir(file_path):
                    shutil.rmtree(file_path)
            except Exception as e:
                print('Failed to delete %s. Reason: %s' % (file_path, e))

# %%
videourl = "https://www.youtube.com/watch?v=TzbvfPaGHl4" #https://www.youtube.com/watch?v=mY4R1uR4gYI"  #"https://www.youtube.com/watch?v=qi3V_ArpDp4" 
to_text = SoundToText(videourl)

# %%
to_text.convert_video_to_audio()
# Out:
# MoviePy - Writing audio in C:\Users\VanessaDuarte\Documents\Maestría\Seminario de Innovación\Backend\Converted results\Converted_audio.wav
# MoviePy - Done.
# Finished the convertion into audio...
# Audio file readed...
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.95628816,
#                            'transcript': 'hola qué tal amiguitos bienvenidos '
#                                          'al canal'},
#                        {   'transcript': 'hola que tal amiguitos bienvenidos '
#                                          'al canal'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.89967024,
#                            'transcript': 'yo soy Patty Martínez'},
#                        {'transcript': 'yo soy Paty Martínez'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.95804888,
#                            'transcript': 'y el día de hoy vamos a hacer unas '
#                                          'deliciosas rajas con crema y elote'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.958049,
#                            'transcript': 'están muy muy fácil de hacer'},
#                        {'transcript': 'están muy muy facil de hacer'}],
#     'final': True}
# result2:
# {   'alternative': [{'confidence': 0.958049, 'transcript': 'vamos a empezar'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.95804894,
#                            'transcript': 'y los ingredientes que vamos a '
#                                          'necesitar son'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.958049,
#                            'transcript': 'tres chiles poblanos grandes'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.958049,
#                            'transcript': 'tatemados desvenados'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.92099631,
#                            'transcript': 'y partidos en rajitas'},
#                        {'transcript': 'y partidos en rayitas'},
#                        {'transcript': 'y partidos en ragitas'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.95804894,
#                            'transcript': 'vamos a necesitar también una taza '
#                                          'de elote'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.95804894,
#                            'transcript': 'una taza y media de crema agria'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.91479445,
#                            'transcript': 'media cebolla partida en julianitas'},
#                        {'transcript': 'media cebolla partido en julianitas'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.958049,
#                            'transcript': 'un cuarto de barra de mantequilla'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.958049,
#                            'transcript': 'y consomé de pollo al gusto'}],
#     'final': True}
# result2:
# {   'alternative': [{'confidence': 0.958049, 'transcript': 'vamos a empezar'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.95804864,
#                            'transcript': 'vamos a empezar por tatemalos chiles '
#                                          'hay muchas maneras de de tatemarlos '
#                                          'unas personas eh los ponen en aceite '
#                                          'otros los ponen en comal yo la '
#                                          'verdad le he cargado los las otras '
#                                          'dos y no me ha gustado es este para '
#                                          'mí esta es la más fácil y la más '
#                                          'práctica ponemos los chiles '
#                                          'directamente en la estufa y tenemos '
#                                          'que estarlos cuidando yo tengo '
#                                          'ahorita eh un poquito más de '
#                                          'habilidad y pongo tres chiles si '
#                                          'ustedes es primera vez que lo hacen '
#                                          'pues háganlo de uno por uno y lo '
#                                          'único que tenemos que estar haciendo '
#                                          'es dándole vuelta viendo que no '
#                                          'estén muy quemados y este y '
#                                          'cambiando los de posición hasta que '
#                                          'estén completamente quemaditos no '
#                                          'muy quemados porque si ustedes los '
#                                          'dejan mucho rato y se queman la piel '
#                                          'del Chile se adelgaza y no sabe tan '
#                                          'bueno entonces así miren vamos a '
#                                          'estar los volteando hasta que estén '
#                                          'todos quemados'},
#                        {   'transcript': 'vamos a empezar por tatemalos chiles '
#                                          'hay muchas maneras de de tatemarlos '
#                                          'unas personas eh los ponen en aceite '
#                                          'otros los ponen en comal yo la '
#                                          'verdad le he cargado los las otras '
#                                          'dos y no me ha gustado es este para '
#                                          'mí esta es la más fácil y la más '
#                                          'práctica ponemos los chiles '
#                                          'directamente en la estufa y tenemos '
#                                          'que estarlos cuidando yo tengo '
#                                          'ahorita eh un poquito más de '
#                                          'habilidad y pongo tres chiles si '
#                                          'ustedes es primera vez que lo hacen '
#                                          'pues háganlo de uno por uno y lo '
#                                          'único que tenemos que estar haciendo '
#                                          'es dándole vuelta viendo que no '
#                                          'estén muy quemados y este y '
#                                          'cambiando los de posición hasta que '
#                                          'estén completamente quemaditos no '
#                                          'muy quemados porque si ustedes los '
#                                          'dejan mucho rato y se queman la piel '
#                                          'del Chile se adelgaza y no sabe tan '
#                                          'bueno entonces así miren vamos a '
#                                          'estar los volteando hasta que estén '
#                                          'todos quemaditos'},
#                        {   'transcript': 'vamos a empezar por tatemalos chiles '
#                                          'hay muchas maneras de de tatemarlos '
#                                          'unas personas eh los ponen en aceite '
#                                          'otros los ponen en comal yo la '
#                                          'verdad le he cargado los las otras '
#                                          'dos y no me ha gustado es este para '
#                                          'mí esta es la más fácil y la más '
#                                          'práctica ponemos los chiles '
#                                          'directamente en la estufa y tenemos '
#                                          'que estarlos cuidando yo tengo '
#                                          'ahorita eh un poquito más de '
#                                          'habilidad y pongo tres chiles si '
#                                          'ustedes es primera vez que lo hacen '
#                                          'pues háganlo de uno por uno y lo '
#                                          'único que tenemos que estar haciendo '
#                                          'es dándole vuelta viendo que no '
#                                          'estén muy quemados y este y '
#                                          'cambiando los de posición hasta que '
#                                          'estén completamente quemaditos no '
#                                          'muy quemados porque si ustedes los '
#                                          'dejan mucho rato y se queman la piel '
#                                          'del Chile se adelgaza y no sabe tan '
#                                          'bueno entonces así miren vamos a '
#                                          'estar los volteando hasta que estén '
#                                          'todos quemaditas'}],
#     'final': True}
# result2:
# []
# Error:
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.95758694,
#                            'transcript': 'miren así es como debe de quedar '
#                                          'todo tatemadito por todos lados pero '
#                                          'no quemado así se les va a despegar '
#                                          'la piel muy muy fácil ahora lo vamos '
#                                          'a meter en una bolsa de plástico '
#                                          'para que suden y así poder '
#                                          'despegarles bien la piel cerramos '
#                                          'bien bien'},
#                        {   'transcript': 'miren así es como debe de quedar '
#                                          'todo tatemadito por todos lados pero '
#                                          'no quemado así se les va a despegar '
#                                          'la piel muy muy fácil ahora lo vamos '
#                                          'a meter en una bolsa de plástico '
#                                          'para que suden y así poder '
#                                          'despegarles bien la piel cerramos '
#                                          'bien bien bien'},
#                        {   'transcript': 'miren así es como debe de quedar '
#                                          'todo tatemadito por todos lados pero '
#                                          'no quemado así se les va a despegar '
#                                          'la piel muy muy fácil ahora lo vamos '
#                                          'a meter en una bolsa de plástico '
#                                          'para que suden y así poder '
#                                          'despegarles bien la piel cerramos '
#                                          'bien'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.95804894,
#                            'transcript': 'y lo vamos a tapar con un secador'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.94195235,
#                            'transcript': 'pues vamos a dejar aquí 15 minutos'},
#                        {'transcript': 'pues vamos a dejar aquí quince minutos'},
#                        {'transcript': 'pues vamos a dejar aquí 15 min'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.958049,
#                            'transcript': 'bueno vamos a empezar'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.958049,
#                            'transcript': 'por poner mantequilla'}],
#     'final': True}
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.92163879,
#                            'transcript': 'yo la pongo así en rebanaditas para '
#                                          'que se derrita más rápido no se nos '
#                                          'vaya a quemar'},
#                        {   'transcript': 'yo la pongo así en rebanaditas para '
#                                          'que se derrita más rápido y no se '
#                                          'nos vaya a quemar'}],
#     'final': True}
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.958049,
#                            'transcript': 'y agregamos la cebolla'}],
#     'final': True}
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.95804888,
#                            'transcript': 'en julianitas vamos a estar aquí '
#                                          'moviendo y hasta que estén '
#                                          'transparentes'}],
#     'final': True}
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.93986076,
#                            'transcript': 'aquí ya está mire ya se ve '
#                                          'transparentaron ahora vamos a '
#                                          'agregarle las rajas'},
#                        {   'transcript': 'aquí ya está mire ya se ve '
#                                          'transparentaron ahora vamos a '
#                                          'agregarle las raja'},
#                        {   'transcript': 'aquí ya están mira ya se ve '
#                                          'transparentaron ahora vamos a '
#                                          'agregarle las rajas'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.93784714,
#                            'transcript': 'yo le dejé algunas semillitas de '
#                                          'Chile para que estuvieran un poquito '
#                                          'picosas si a ustedes les gusta eso '
#                                          'es lo que pueden hacer le dejan'},
#                        {   'transcript': 'yo le dejé algunas semillitas de '
#                                          'Chile para que estuvieran un poquito '
#                                          'picosas si a ustedes les gusta eso '
#                                          'lo que pueden hacer le dejan'},
#                        {   'transcript': 'yo le dejé algunas semillitas de '
#                                          'Chile para que estuvieran un poquito '
#                                          'picosas si a ustedes les gusta eso '
#                                          'es lo que pueden hacer le deja'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.94969642,
#                            'transcript': 'unas cuantas semillitas y va a salir '
#                                          'picositas las rajas si no no hay que '
#                                          'dejarle nada nada porque las '
#                                          'semillas son es lo que enchila más'},
#                        {   'transcript': 'unas cuantas semillitas y va a salir '
#                                          'picositas las rajas si no no hay que '
#                                          'dejarle nada nada porque las '
#                                          'semillas es lo que enchila más'},
#                        {   'transcript': 'unas cuantas semillitas y va a salir '
#                                          'picositas las rajas si no no hay que '
#                                          'dejarle nada nada porque las '
#                                          'semillas son es lo que enchila mas'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.958049,
#                            'transcript': 'ahora le agregamos el elote'}],
#     'final': True}
# result2:
# {   'alternative': [{'confidence': 0.958049, 'transcript': 'y revolvemos'}],
#     'final': True}
# result2:
# []
# Error:
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.93321431,
#                            'transcript': 'revolvemos bien y me encanta como se '
#                                          'ven los colores siempre me gustan '
#                                          'mucho los colores de la de la '
#                                          'comida'},
#                        {   'transcript': 'revolvemos bien y me encanta como se '
#                                          'ven los colores siempre me gustan '
#                                          'mucho los colores de la comida'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.94714767,
#                            'transcript': 'hay que ponerle sus colorcitos y se '
#                                          've muy rico'},
#                        {   'transcript': 'hay que ponerle sus colorcitos y se '
#                                          've muy rica'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.95804894,
#                            'transcript': 'y ahora vamos a agregar la crema'}],
#     'final': True}
# result2:
# []
# Error:
# result2:
# []
# Error:
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.94297391,
#                            'transcript': 'también mucha gente lo hace con '
#                                          'media crema también se puede yo '
#                                          'utilizo crema agria'},
#                        {   'transcript': 'también mucha gente lo hace con '
#                                          'media crema también se puede yo '
#                                          'utilizo crema crema agria'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.95804894,
#                            'transcript': 'este vamos a poner una taza y media '
#                                          'de crema'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.95804894,
#                            'transcript': 'a mí me gusta que salga bien bien '
#                                          'cremosita'},
#                        {   'transcript': 'a mí me gusta que salga bien bien '
#                                          'cremosito'}],
#     'final': True}
# result2:
# []
# Error:
# result2:
# []
# Error:
# result2:
# {   'alternative': [{'confidence': 0.958049, 'transcript': 'revolvemos bien'}],
#     'final': True}
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.92824531,
#                            'transcript': 'y aquí lo vamos a dejar que hierva '
#                                          'unos 5 minutos'},
#                        {   'transcript': 'y aquí lo vamos a dejar que hierva '
#                                          'unos cinco minutos'}],
#     'final': True}
# result2:
# []
# Error:
# result2:
# []
# Error:
# result2:
# []
# Error:
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.93168306,
#                            'transcript': 'que quede bien bien mezcladito vamos '
#                                          'a agregarle el consomé'},
#                        {   'transcript': 'que quede bien bien mezclado vamos a '
#                                          'agregarle el consomé'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.95804888,
#                            'transcript': 'poquito y probamos y el consomé pues '
#                                          'se pone al gusto vamos a revolver '
#                                          'bien'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.93423712,
#                            'transcript': 'y ya que hierva unos cinco minutos '
#                                          'entonces probamos de sal '
#                                          'rectificamos y le hace falta pues le '
#                                          'ponemos consomé'},
#                        {   'transcript': 'y ya que hierva unos cinco minutos '
#                                          'entonces probamos de sal '
#                                          'rectificamos si le hace falta pues '
#                                          'le ponemos consomé'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.9247939,
#                            'transcript': 'las tapamos y las dejamos 5 minutos'},
#                        {   'transcript': 'las tapamos y las dejamos cinco '
#                                          'minutos'},
#                        {'transcript': 'hasta tapamos y las dejamos 5 minutos'}],
#     'final': True}
# result2:
# []
# Error:
# result2:
# {   'alternative': [   {   'confidence': 0.95804888,
#                            'transcript': 'ya pasaron los cinco minutos y miren '
#                                          'la cremita se pinta de color verde '
#                                          'de los chiles'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.9418354,
#                            'transcript': 'y esto es todo esta raja ya están '
#                                          'listas para un taquito duermen en '
#                                          'taquito porque como es carne asada '
#                                          'vamos a hacer tacos ay qué rico '
#                                          'vamos a probar se les va a hacer '
#                                          'agua la boca está delicioso y los '
#                                          'los chinos están chidos eh pero bien '
#                                          'cremosa'},
#                        {   'transcript': 'y esto es todo estas rajas ya están '
#                                          'listas para un taquito duermen en '
#                                          'taquito porque como es carne asada '
#                                          'vamos a hacer tacos ay qué rico '
#                                          'vamos a probar se les va a hacer '
#                                          'agua la boca está delicioso y los '
#                                          'los chinos están chidos eh pero bien '
#                                          'cremosa'},
#                        {   'transcript': 'y esto es todo esta raja ya están '
#                                          'listas para un taquito duermen en '
#                                          'taquito porque como es carne asada '
#                                          'vamos a hacer tacos ay qué rico '
#                                          'vamos a probar se les va a hacer '
#                                          'agua la boca está delicioso y los '
#                                          'los chinos están chidos eh pero bien '
#                                          'cremosa ah'},
#                        {   'transcript': 'y esto es todo estas rajas ya están '
#                                          'listas para un taquito duermen en '
#                                          'taquito porque como es carne asada '
#                                          'vamos a hacer tacos ay qué rico '
#                                          'vamos a probar se les va a hacer '
#                                          'agua la boca está delicioso y los '
#                                          'los chinos están chidos eh pero bien '
#                                          'cremosa ah'},
#                        {   'transcript': 'y esto es todo esta raja ya están '
#                                          'listas para un taquito duermen en '
#                                          'taquito porque como es carne asada '
#                                          'vamos a hacer tacos ay qué rico '
#                                          'vamos a probar se les va hacer agua '
#                                          'la boca está delicioso y los los '
#                                          'chinos están chidos eh pero bien '
#                                          'cremosa'}],
#     'final': True}
# result2:
# {   'alternative': [   {   'confidence': 0.95804894,
#                            'transcript': 'bueno pues muchas gracias nos vemos '
#                                          'adiós'}],
#     'final': True}
#
# Full text: hola qué tal amiguitos bienvenidos al canal yo soy Patty Martínez y el día de hoy vamos a hacer unas deliciosas rajas con crema y elote están muy muy fácil de hacer vamos a empezar y los ingredientes que vamos a necesitar son tres chiles poblanos grandes tatemados desvenados y partidos en rajitas vamos a necesitar también una taza de elote una taza y media de crema agria media cebolla partida en julianitas un cuarto de barra de mantequilla y consomé de pollo al gusto vamos a empezar vamos a empezar por tatemalos chiles hay muchas maneras de de tatemarlos unas personas eh los ponen en aceite otros los ponen en comal yo la verdad le he cargado los las otras dos y no me ha gustado es este para mí esta es la más fácil y la más práctica ponemos los chiles directamente en la estufa y tenemos que estarlos cuidando yo tengo ahorita eh un poquito más de habilidad y pongo tres chiles si ustedes es primera vez que lo hacen pues háganlo de uno por uno y lo único que tenemos que estar haciendo es dándole vuelta viendo que no estén muy quemados y este y cambiando los de posición hasta que estén completamente quemaditos no muy quemados porque si ustedes los dejan mucho rato y se queman la piel del Chile se adelgaza y no sabe tan bueno entonces así miren vamos a estar los volteando hasta que estén todos quemados miren así es como debe de quedar todo tatemadito por todos lados pero no quemado así se les va a despegar la piel muy muy fácil ahora lo vamos a meter en una bolsa de plástico para que suden y así poder despegarles bien la piel cerramos bien bien y lo vamos a tapar con un secador pues vamos a dejar aquí 15 minutos bueno vamos a empezar por poner mantequilla yo la pongo así en rebanaditas para que se derrita más rápido no se nos vaya a quemar y agregamos la cebolla en julianitas vamos a estar aquí moviendo y hasta que estén transparentes aquí ya está mire ya se ve transparentaron ahora vamos a agregarle las rajas yo le dejé algunas semillitas de Chile para que estuvieran un poquito picosas si a ustedes les gusta eso es lo que pueden hacer le dejan unas cuantas semillitas y va a salir picositas las rajas si no no hay que dejarle nada nada porque las semillas son es lo que enchila más ahora le agregamos el elote y revolvemos revolvemos bien y me encanta como se ven los colores siempre me gustan mucho los colores de la de la comida hay que ponerle sus colorcitos y se ve muy rico y ahora vamos a agregar la crema también mucha gente lo hace con media crema también se puede yo utilizo crema agria este vamos a poner una taza y media de crema a mí me gusta que salga bien bien cremosita revolvemos bien y aquí lo vamos a dejar que hierva unos 5 minutos que quede bien bien mezcladito vamos a agregarle el consomé poquito y probamos y el consomé pues se pone al gusto vamos a revolver bien y ya que hierva unos cinco minutos entonces probamos de sal rectificamos y le hace falta pues le ponemos consomé las tapamos y las dejamos 5 minutos ya pasaron los cinco minutos y miren la cremita se pinta de color verde de los chiles y esto es todo esta raja ya están listas para un taquito duermen en taquito porque como es carne asada vamos a hacer tacos ay qué rico vamos a probar se les va a hacer agua la boca está delicioso y los los chinos están chidos eh pero bien cremosa bueno pues muchas gracias nos vemos adiós
# Descripción del Video:
# Para comunicarte conmigo:  aquepaty@hotmail.com
#
# https://web.facebook.com/aquepatys/
#
# https://www.instagram.com/aquepaty/
#
# https://www.pinterest.com/aquepaty/
