# %%
pip install opencv-python --upgrade setuptools wheel youtube_dl install pafy pytube pytesseract setuptools wheel spacy language_tool_python panda
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in /Users/jasura/Library/Python/3.9/lib/python/site-packages (4.7.0.72)
# Requirement already satisfied: setuptools in /Users/jasura/Library/Python/3.9/lib/python/site-packages (67.6.1)
# Requirement already satisfied: wheel in /Users/jasura/Library/Python/3.9/lib/python/site-packages (0.40.0)
# Requirement already satisfied: youtube_dl in /Users/jasura/Library/Python/3.9/lib/python/site-packages (2021.12.17)
# Requirement already satisfied: install in /Users/jasura/Library/Python/3.9/lib/python/site-packages (1.3.5)
# Requirement already satisfied: pafy in /Users/jasura/Library/Python/3.9/lib/python/site-packages (0.5.5)
# Requirement already satisfied: pytube in /Users/jasura/Library/Python/3.9/lib/python/site-packages (12.1.3)
# Requirement already satisfied: pytesseract in /Users/jasura/Library/Python/3.9/lib/python/site-packages (0.3.10)
# Requirement already satisfied: spacy in /Users/jasura/Library/Python/3.9/lib/python/site-packages (3.5.1)
# Collecting spacy
#   Using cached spacy-3.5.2-cp39-cp39-macosx_10_9_x86_64.whl (6.9 MB)
# Requirement already satisfied: language_tool_python in /Users/jasura/Library/Python/3.9/lib/python/site-packages (2.7.1)
# Requirement already satisfied: panda in /Users/jasura/Library/Python/3.9/lib/python/site-packages (0.3.1)
# Requirement already satisfied: numpy>=1.19.3 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from opencv-python) (1.24.2)
# Requirement already satisfied: packaging>=21.3 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pytesseract) (23.0)
# Requirement already satisfied: Pillow>=8.0.0 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pytesseract) (9.4.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from spacy) (6.3.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from spacy) (2.0.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from spacy) (1.10.7)
# Requirement already satisfied: jinja2 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: pathy>=0.10.0 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from spacy) (0.10.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from spacy) (1.0.9)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from spacy) (2.4.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from spacy) (2.28.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from spacy) (8.1.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from spacy) (4.65.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from spacy) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from spacy) (1.0.4)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from spacy) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from jinja2->spacy) (2.1.2)
# Installing collected packages: spacy
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.5.1
#     Uninstalling spacy-3.5.1:
#       Successfully uninstalled spacy-3.5.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# errant 2.3.3 requires spacy<3,>=2.2.0, but you have spacy 3.5.2 which is incompatible.
# Successfully installed spacy-3.5.2
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pattern
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pattern in /Users/jasura/Library/Python/3.9/lib/python/site-packages (3.6)
# Requirement already satisfied: scipy in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pattern) (1.10.1)
# Requirement already satisfied: cherrypy in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pattern) (18.8.0)
# Requirement already satisfied: feedparser in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pattern) (6.0.10)
# Requirement already satisfied: lxml in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pattern) (4.9.2)
# Requirement already satisfied: pdfminer.six in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pattern) (20221105)
# Requirement already satisfied: python-docx in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pattern) (0.8.11)
# Requirement already satisfied: numpy in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pattern) (1.24.2)
# Requirement already satisfied: backports.csv in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pattern) (1.0.7)
# Requirement already satisfied: future in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from pattern) (0.18.2)
# Requirement already satisfied: requests in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pattern) (2.28.2)
# Requirement already satisfied: mysqlclient in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pattern) (2.1.1)
# Requirement already satisfied: nltk in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pattern) (3.8.1)
# Requirement already satisfied: beautifulsoup4 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pattern) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4->pattern) (2.4)
# Requirement already satisfied: portend>=2.1.1 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from cherrypy->pattern) (3.1.0)
# Requirement already satisfied: cheroot>=8.2.1 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from cherrypy->pattern) (9.0.0)
# Requirement already satisfied: jaraco.collections in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from cherrypy->pattern) (4.1.0)
# Requirement already satisfied: zc.lockfile in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from cherrypy->pattern) (3.0.post1)
# Requirement already satisfied: more-itertools in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from cherrypy->pattern) (9.1.0)
# Requirement already satisfied: sgmllib3k in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from feedparser->pattern) (1.0.0)
# Requirement already satisfied: tqdm in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from nltk->pattern) (4.65.0)
# Requirement already satisfied: click in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from nltk->pattern) (8.1.3)
# Requirement already satisfied: joblib in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from nltk->pattern) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from nltk->pattern) (2023.3.23)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pdfminer.six->pattern) (3.1.0)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pdfminer.six->pattern) (39.0.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from requests->pattern) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from requests->pattern) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from requests->pattern) (2022.12.7)
# Requirement already satisfied: jaraco.functools in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from cheroot>=8.2.1->cherrypy->pattern) (3.6.0)
# Requirement already satisfied: six>=1.11.0 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from cheroot>=8.2.1->cherrypy->pattern) (1.15.0)
# Requirement already satisfied: cffi>=1.12 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from cryptography>=36.0.0->pdfminer.six->pattern) (1.15.1)
# Requirement already satisfied: tempora>=1.8 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from portend>=2.1.1->cherrypy->pattern) (5.2.2)
# Requirement already satisfied: jaraco.text in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from jaraco.collections->cherrypy->pattern) (3.11.1)
# Requirement already satisfied: setuptools in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from zc.lockfile->cherrypy->pattern) (67.6.1)
# Requirement already satisfied: pycparser in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->pattern) (2.21)
# Requirement already satisfied: pytz in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->pattern) (2022.7.1)
# Requirement already satisfied: autocommand in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from jaraco.text->jaraco.collections->cherrypy->pattern) (2.2.2)
# Requirement already satisfied: jaraco.context>=4.1 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from jaraco.text->jaraco.collections->cherrypy->pattern) (4.3.0)
# Requirement already satisfied: inflect in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from jaraco.text->jaraco.collections->cherrypy->pattern) (6.0.4)
# Requirement already satisfied: pydantic>=1.9.1 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from inflect->jaraco.text->jaraco.collections->cherrypy->pattern) (1.10.7)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pydantic>=1.9.1->inflect->jaraco.text->jaraco.collections->cherrypy->pattern) (4.5.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python3 -m spacy download es_core_news_lg

# %%
# !python3 -m pip install -U pip

# %%
pip install --upgrade setuptools
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install  openpyxl
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import os
import numpy as np
import pytesseract
from pytesseract import Output
from pytube import YouTube
from PIL import Image, ImageEnhance
import pandas as pd

import spacy
from spacy.tokens import Token
import re
import language_tool_python

#from pattern.es import pluralize
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import cv2
#       2 import os
#       3 import numpy as np
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:982, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:925, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1414, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1383, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1347, in _path_importer_cache(cls, path)
#
# PermissionError: [Errno 1] Operation not permitted

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
#declaracion de las librerias de NPL
nlp = spacy.load("es_core_news_lg")
tool = language_tool_python.LanguageTool('es')

# %%
"""
Obtiene los ingredientes del dataset.
"""
def get_ingredients_from_file(dataset):
    return pd.read_excel(dataset)

# %%
"""
Define la palabra y la convierte a plural usando la función pluralize().
""" 
def to_plural(word):
    # #https://stackoverflow.com/questions/31387905/converting-plural-to-singular-in-a-text-file-with-python
    # Installing NLTK data to import
    # and run en module of pattern
    #nltk.download('popular')

    return pluralize(word)

# %%
"""
Define la palabra y la convierte a singular usando la función singularize().
""" 
def to_singular(word):
    # # Import the NLTK module https://www.geeksforgeeks.org/python-program-to-convert-singular-to-plural/
    return singularize(word)

# %%
"""
Obtiene los ingredientes del dataset.
"""
def get_ingredients_from_file(dataset):
    return pd.read_excel(dataset)

# %%
"""
Preprocesar información (se convierte la primera columna a minusculas y se eliminan NAN)
""" 
def get_ingredients(main_ingredient):
    basic_ingredients = main_ingredient.dropna().T.drop_duplicates().T

    ingredients = []
    for ing in basic_ingredients:
        #ingredients.append(to_plural(ing))
        #ingredients.append(to_singular(ing))
        
        ingredients.append(ing)
        
    return ingredients

# %%
main_ingredient = ingredients_set.iloc[:, 0].str.lower()

# %%
# Se obtienen los datos de los datasets
ingredients = get_ingredients(main_ingredient)

# %%
ingredients.append("tortillas")

# %%
'tortillas' in ingredients
# Out:
# True

# %%
'''evaluamos la semantica de la palabra para ver si esta correctamente formulada la oracion 
o hay textos basura, pero validos en español'''
def semantic(token):
    #validar si la estructura de la oracion no se cumple
    if token.pos_ in ['NUM', 'PUNCT', 'VERB', 'NOUN', 'ADJ', 'ADV', 'PROPN']:
        if (not token.is_alpha and token.pos_ not in ['NUM', 'PUNCT'] ) or (token.pos_ == 'PUNCT' and token.i == 0):
            return False
        return True
    else:
        return False

def consonant(token):
    alphabet_es = 'abcdefghijklmnñopqrstuvwxyz'
    vowels = 'aeiou'
    text = token.text.lower()
    return (text in alphabet_es) and (text not in vowels)


#evaluamos la sintaxis de la letra/palabra para ver si no es texto basura 
def syntax(token):
    if token._.is_ingredient:
        return True
    
    if token.is_oov or not token._.is_spanish:
        # Verificamos si la palabra es desconocida en el modelo o no es espa;ol
        return False
    
    if token.is_alpha and not token.is_stop :
        '''verificamos si el token es una palabra o no y si no es una palabra vacía 
        .is_alpha se utiliza para verificar si un token es una palabra o no.
        booleano que indica si el token es una palabra vacía o de stop. (y, a, la ....)'''

        if token._.is_semantic and not token._.is_consonant:
            '''validamos si es semanticamente correcto y si no es una vocal, asi devolvemos TRUE 
            a las palabras (que si cumplen con estas condiciones)'''
            return True
        
        return False
    
    return True


# Verificamos si la palabra existe en el vocabulario del modelo en ES
def spanish_word(token):
    if nlp.vocab.has_vector(token.text) or token._.is_ingredient:
        return True
    return False

def ingredient(token):
    return token.text.lower() in ingredients is not False

def symbol(token):
    # Expresión regular que busca cualquier caracter que no sea una letra, número o espacio en blanco
    patron = r'[^a-zA-Z1-9ñÑáéíóúÁÉÍÓÚüÜ\d\s/\d.]'
    # Buscamos el patrón en el texto
    res = re.search(patron, token.text)
    # Si se encuentra algún símbolo devuelve True
    return res is not False

#creamos nuestras propiedades personalizadas
Token.set_extension('is_semantic', getter=semantic, force=True)
Token.set_extension('is_syntax', getter=syntax, force=True)
Token.set_extension('is_spanish', getter=spanish_word, force=True)
Token.set_extension('is_consonant', getter=consonant, force=True)
Token.set_extension('is_symbol', getter=symbol, force=True)
Token.set_extension('is_ingredient', getter=ingredient, force=True)

# %%
def grammar_validate(sentence):
    matches = tool.check(sentence)
    if len(matches) > 0:
        #La oración tiene errores sintácticos.
        return False
    else:
        #La oración es gramaticalmente correcta.
        return True

def word_validate(sentence):
    doc_es = nlp(sentence)
    words =  []

    # Expresión regular que busca cualquier caracter que no sea una letra, número o espacio en blanco
    patron = r'[^a-zA-Z1-9ñÑáéíóúÁÉÍÓÚüÜ\d\s/\d.]'
    validate = ['NUM', 'PUNCT']

    is_valid = []
    have_ingredient = False

    black_list = ["ol", "ae", "cu", "re", "cis", "ea", "pe", '/']

    for token in doc_es:

        # Buscamos el patrón en el texto
        res = re.search(patron, token.text)

        # Si se encuentra algún símbolo devuelve True
        is_symbol = res is not None


        print(token.text, " alpha:", token.is_alpha, " stop: " , token.is_stop, " desconocida: ", token.is_oov, token.pos_)
        print("    sem:", token._.is_semantic,  "syntax:", token._.is_syntax, "spanish:", token._.is_spanish, " is_consonant", token._.is_consonant, "is_ingredient", token._.is_ingredient, "is_symbol", is_symbol )



        if not is_symbol:
            print("::NO es simbolo")
            if token.text in black_list :
                continue
            
            if token._.is_ingredient:
                have_ingredient = True
                words.append(token.text.capitalize())
                is_valid.append(True)
                continue

            #if token.tag_ not in validate:

                #is_spanish = spanish_word(token)
                #is_valid = all([token._.is_semantic, token._.is_spanish, token._.is_syntax])

                #if is_valid :
                #    words.append(token.text)
            #else:
            #    words.append(token.text)

            if all([token._.is_semantic, token._.is_spanish, token._.is_syntax]):
                words.append(token.text)
                is_valid.append(True)
                continue
        # else:
        #     is_valid.append(False)


    # if have_ingredient : 

    #     print( )
    #     return ' '.join(words)
    
    
    # if all([valid for valid in is_valid]):
    #     return ' '.join(words)
    # else:
    #     return None

        #print("La oración es inválida.")
    
    sentence = ' '.join(words)
    grammar  = grammar_validate(sentence)
    print("::" , sentence, "word",  words, "::grammar:", grammar)
    
    if not grammar:
        return None
    return sentence

# %%
class Video:
    def __init__(self, path, url):
        self.path = path
        self.videoUrl = url
        self.yt = self.Download()
        #self.localUrl = ''
        #self.yt = ''
        
    def Download(self):
        #por ahora para archivos de internet
        file = self.Network()
        print(file)
        return file

    def Network(self):
        yt = YouTube(self.videoUrl)
        yt = yt.streams.filter(progressive=True, file_extension='mp4').order_by('resolution').desc().first()
        if not os.path.exists(self.path):
            os.makedirs(self.path)
        localUrl = yt.download(self.path)
        self.localUrl = localUrl
        return yt

#'https://www.youtube.com/watch?v=REAFtXGnpKU'

# %%
video = Video('C:/Users/jasura/Documents/maestria/seminario',
 'https://www.youtube.com/watch?v=XE6epSyQrkw' )
# Out:
# <Stream: itag="22" mime_type="video/mp4" res="720p" fps="25fps" vcodec="avc1.64001F" acodec="mp4a.40.2" progressive="True" type="video">

# %%
video.localUrl
# Out:
# '/Users/jasura/Documents/maestria/seminario/javan-vrc/backend/C:/Users/jasura/Documents/maestria/seminario/Masa para tacos wraps  Rapiditas Caseras - CUKit!.mp4'

# %%
def img_process(img):

    #convertimos a RGB
    # color_coverted = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  
    # # Displaying the converted image
    # image = Image.fromarray(color_coverted)

    # # agregado de sharpness y contrast a la  imagen
    # enhancer1 = ImageEnhance.Sharpness(image)
    # enhancer2 = ImageEnhance.Contrast(image)
    # img_edit = enhancer1.enhance(20.0)
    # img_edit = enhancer2.enhance(1.5)

    # cv_img = cv2.cvtColor(np.array(img_edit), cv2.COLOR_RGB2BGR)

    # Convertir la imagen a escala de grises
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Aplicar una operación morfológica para eliminar el ruido
    kernel = np.ones((3,3), np.uint8)
    opening = cv2.morphologyEx(gray, cv2.MORPH_OPEN, kernel)
    
    # Aplicar una operación de threshold para aumentar el contraste
    thresh = cv2.threshold(opening, 200, 255, cv2.THRESH_BINARY_INV)[1]
    #plt.imshow(thresh);
    # Encontrar contornos en la imagen thresholdada
    contours, hierarchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Inicializar una lista para almacenar los rectángulos que contienen el texto
    rects = []
    
    # Recorrer cada contorno
    for cnt in contours:
        # Obtener el rectángulo que encierra el contorno
        x, y, w, h = cv2.boundingRect(cnt)
        
        # Agregar el rectángulo a la lista si cumple con ciertos criterios
        if w > 50 and h > 50:
            rects.append((x, y, w, h))


    # Recorrer cada rectángulo
    for rect in rects:
        x, y, w, h = rect
        roi = thresh[y:y+h, x:x+w]
        
    #convertimos a RGB
    #color_coverted = cv2.cvtColor(roi, cv2.COLOR_BGR2RGB)
  
    # Displaying the converted image
    pil_image = Image.fromarray(roi)

    return pil_image

# %%
def extract_text_img(img):
    
    image = img_process(img)

    # Utilizar OCR (Reconocimiento Óptico de Caracteres) para extraer el texto de la región de interés
    ocr = pytesseract.image_to_string(image)

    print(ocr, len(ocr))


    ocr_validate = word_validate(ocr.lower())

    print("::ocr_validate", ocr_validate)
    if not ocr_validate:
        return None

    #print(text)
    return ocr_validate

# %%
cam = cv2.VideoCapture(video.localUrl)

# %%
complete_text = []
prev_text = ""

# Establecer un nivel mínimo de similitud exigido:
nivel_minimo = 0.8



while(cam.isOpened()):
    # Leer el siguiente fotograma
    ret, frame = cam.read()

    # color_coverted = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
  
    
    # # Displaying the converted image
    # pil_image = Image.fromarray(color_coverted)

    # Si no hay más fotogramas, salir del bucle
    if not ret:
        break

    # Validamos que la imagen no sea 100% negra
    is_black = not np.any(frame)

    #si la img es negra ignoramos
    if is_black:
        continue

    # Utilizar funcion extract_text extraer el texto de la imagen
    text = extract_text_img(frame)


    if text :


        print(prev_text," - ", text)
        # Obtener el objeto Doc para cada texto:
        pt = nlp(prev_text)
        nt = nlp(text)

        # Calcular la similitud entre los textos:
        similitud = pt.similarity(nt)

        #TODO agregar todos los coincidentes en un array y luego seleccionar el que tenga mas letras, si se comparte la misma cantidad con otro solo se  seleccionara 1


        if similitud >= nivel_minimo:
            #print('Los textos son similares.')
            continue
        else:
            #print('Los textos no son suficientemente similares.')
            prev_text = text
            complete_text.append(text)
    
    # Imprimir el texto extraído

print(' '.join(complete_text))
# Liberar la cámara
cam.release()
# Out:
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
# * te,
#  6
# *  alpha: False  stop:  False  desconocida:  False SYM
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# te  alpha: True  stop:  True  desconocida:  False PRON
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ,  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
# Oe ee,
#  7
# oe  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ee  alpha: True  stop:  False  desconocida:  False PROPN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ,  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: oe ee word ['oe', 'ee'] ::grammar: False
# ::ocr_validate None
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
# ———_$ am
#  9
# —  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# —  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# —  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# _  alpha: False  stop:  False  desconocida:  False ADJ
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# $  alpha: False  stop:  False  desconocida:  False NOUN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# am  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: am word ['am'] ::grammar: False
# ::ocr_validate None
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
#  0
# ::  word [] ::grammar: True
# ::ocr_validate
# ee CUK# cuK ites __
#  20
# ee  alpha: True  stop:  False  desconocida:  False PRON
#     sem: False syntax: False spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cuk  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# #  alpha: False  stop:  False  desconocida:  False PROPN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# cuk  alpha: True  stop:  False  desconocida:  True ADJ
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ites  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# _  alpha: False  stop:  False  desconocida:  False ADJ
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# _  alpha: False  stop:  False  desconocida:  False ADJ
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: ites word ['ites'] ::grammar: False
# ::ocr_validate None
# ee CUKs: CUB IT.COMs _—
#  24
# ee  alpha: True  stop:  False  desconocida:  False PRON
#     sem: False syntax: False spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cuks  alpha: True  stop:  False  desconocida:  True ADJ
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# cub  alpha: True  stop:  False  desconocida:  False PROPN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# it.coms  alpha: False  stop:  False  desconocida:  True AUX
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# _  alpha: False  stop:  False  desconocida:  False ADJ
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# —  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: cub word ['cub'] ::grammar: False
# ::ocr_validate None
# > 8.4
#
# IDM ANAS
#
# CUK i CUK IT.caM
#  34
# >  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# 8.4  alpha: False  stop:  False  desconocida:  False ADJ
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# idm  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# anas  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cuk  alpha: True  stop:  False  desconocida:  True ADJ
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# i  alpha: True  stop:  False  desconocida:  False CCONJ
#     sem: False syntax: False spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cuk  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# it.cam  alpha: False  stop:  False  desconocida:  True PROPN
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: anas word ['anas'] ::grammar: True
# ::ocr_validate anas
#   -  anas
# /var/folders/fk/k827gpdx4qg96rvjc3n5s7b80000gn/T/ipykernel_21132/1942833239.py:43: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   similitud = pt.similarity(nt)
# — CUK I! _ CU IT.COM
#  21
# —  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# cuk  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# i  alpha: True  stop:  False  desconocida:  False CCONJ
#     sem: False syntax: False spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# !  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# _  alpha: False  stop:  False  desconocida:  False ADJ
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# cu  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# it.com  alpha: False  stop:  False  desconocida:  True NUM
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ::  word [] ::grammar: True
# ::ocr_validate
# MEXICANAS
#
# — CUKi(’ CU IT.coM
#  30
# mexicanas  alpha: True  stop:  False  desconocida:  False ADJ
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# —  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# cuki  alpha: True  stop:  False  desconocida:  True NOUN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# (  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# ’  alpha: False  stop:  False  desconocida:  False NOUN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# cu  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# it.com  alpha: False  stop:  False  desconocida:  True PROPN
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: mexicanas word ['mexicanas'] ::grammar: True
# ::ocr_validate mexicanas
# anas  -  mexicanas
# ° MEXICANAS
# —— CUKi/’ UK ITcom _
#  33
# °  alpha: False  stop:  False  desconocida:  False NUM
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# mexicanas  alpha: True  stop:  False  desconocida:  False ADJ
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# —  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# —  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# cuki/  alpha: False  stop:  False  desconocida:  True PROPN
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ’  alpha: False  stop:  False  desconocida:  False SYM
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# uk  alpha: True  stop:  False  desconocida:  False PROPN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# itcom  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# _  alpha: False  stop:  False  desconocida:  False PROPN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: mexicanas uk word ['mexicanas', 'uk'] ::grammar: False
# ::ocr_validate None
# TORTILLAS
#
# MEXICANAS
#
# —— CUKi(’ CuK IT.com
#  43
# tortillas  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient True is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# mexicanas  alpha: True  stop:  False  desconocida:  False ADJ
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# —  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# —  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# cuki  alpha: True  stop:  False  desconocida:  True NOUN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# (  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# ’  alpha: False  stop:  False  desconocida:  False NOUN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# cuk  alpha: True  stop:  False  desconocida:  True ADJ
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# it.com  alpha: False  stop:  False  desconocida:  True PROPN
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: Tortillas mexicanas word ['Tortillas', 'mexicanas'] ::grammar: True
# ::ocr_validate Tortillas mexicanas
# mexicanas  -  Tortillas mexicanas
# T-
#
# P_
#
# q
# oe
#
# Kae
#
# ee.
#
# ~:
#
# TORTITEAS
#
# MEXICANAS
#
# CUKi(’ ss CUK IT.com
#  71
# t-  alpha: False  stop:  False  desconocida:  False PROPN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# p  alpha: True  stop:  False  desconocida:  False PROPN
#     sem: True syntax: False spanish: True  is_consonant True is_ingredient False is_symbol False
# ::NO es simbolo
# _  alpha: False  stop:  False  desconocida:  False PROPN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# q  alpha: True  stop:  False  desconocida:  False PART
#     sem: False syntax: False spanish: True  is_consonant True is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# oe  alpha: True  stop:  False  desconocida:  False INTJ
#     sem: False syntax: False spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# kae  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ee  alpha: True  stop:  False  desconocida:  False INTJ
#     sem: False syntax: False spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# .  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ~  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# :  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# tortiteas  alpha: True  stop:  False  desconocida:  True ADJ
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# mexicanas  alpha: True  stop:  False  desconocida:  False ADJ
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cuki  alpha: True  stop:  False  desconocida:  True NOUN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# (  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# ’  alpha: False  stop:  False  desconocida:  False NOUN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# ss  alpha: True  stop:  False  desconocida:  False PROPN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cuk  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# it.com  alpha: False  stop:  False  desconocida:  True PROPN
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: . mexicanas ss word ['.', 'mexicanas', 'ss'] ::grammar: False
# ::ocr_validate None
# os ‘ : TORTILLAS
#
# — CUKi(’ — CUK-ITCoM
#  39
# os  alpha: True  stop:  True  desconocida:  False PRON
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ‘  alpha: False  stop:  False  desconocida:  False SYM
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# :  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# tortillas  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient True is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# —  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# cuki  alpha: True  stop:  False  desconocida:  True NOUN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# (  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# ’  alpha: False  stop:  False  desconocida:  False NOUN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# —  alpha: False  stop:  False  desconocida:  False X
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# cuk-itcom  alpha: False  stop:  False  desconocida:  True ADJ
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol True
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: Tortillas word ['Tortillas'] ::grammar: True
# ::ocr_validate Tortillas
# mexicanas  -  Tortillas
# qe
# . <a
#
# ~~ 2
#
# oe.
#
# é
# ee
#
# TORTILLAS
#
# MEXICANAS
#
# CUKi(’ ss CUK IT.com
#  69
# qe  alpha: True  stop:  False  desconocida:  False INTJ
#     sem: False syntax: False spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# .  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# <  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# a  alpha: True  stop:  True  desconocida:  False ADP
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ~~  alpha: False  stop:  False  desconocida:  False NOUN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# 2  alpha: False  stop:  False  desconocida:  False NUM
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# oe  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# .  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# é  alpha: True  stop:  False  desconocida:  False CCONJ
#     sem: False syntax: False spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ee  alpha: True  stop:  False  desconocida:  False INTJ
#     sem: False syntax: False spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# tortillas  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient True is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# mexicanas  alpha: True  stop:  False  desconocida:  False ADJ
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cuki  alpha: True  stop:  False  desconocida:  True NOUN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# (  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# ’  alpha: False  stop:  False  desconocida:  False NOUN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# ss  alpha: True  stop:  False  desconocida:  False PROPN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cuk  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# it.com  alpha: False  stop:  False  desconocida:  True PROPN
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: . 2 oe . Tortillas mexicanas ss word ['.', '2', 'oe', '.', 'Tortillas', 'mexicanas', 'ss'] ::grammar: False
# ::ocr_validate None
# Se
# “Meee
#
# S ‘ ; TORTILLAS
#
# ee CUK it’ _ CUK-IT.COM
#  51
# se  alpha: True  stop:  True  desconocida:  False PRON
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# “  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# meee  alpha: True  stop:  False  desconocida:  True NOUN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# s  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: False spanish: True  is_consonant True is_ingredient False is_symbol False
# ::NO es simbolo
# ‘  alpha: False  stop:  False  desconocida:  False NOUN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# ;  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# tortillas  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient True is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ee  alpha: True  stop:  False  desconocida:  False PROPN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cuk  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# it  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ’  alpha: False  stop:  False  desconocida:  False NOUN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# _  alpha: False  stop:  False  desconocida:  False ADJ
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# cuk-it.com  alpha: False  stop:  False  desconocida:  True NOUN
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol True
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: Tortillas ee it word ['Tortillas', 'ee', 'it'] ::grammar: False
# ::ocr_validate None
# = ‘ - TORTILLAS
#
# MEXICANAS
#
# ee CUKi(/ ss CUK-IT.com
#  52
# =  alpha: False  stop:  False  desconocida:  False NOUN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# ‘  alpha: False  stop:  False  desconocida:  False SYM
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# -  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# tortillas  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient True is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# mexicanas  alpha: True  stop:  False  desconocida:  False ADJ
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ee  alpha: True  stop:  False  desconocida:  False INTJ
#     sem: False syntax: False spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cuki(/  alpha: False  stop:  False  desconocida:  True PROPN
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol True
# ss  alpha: True  stop:  False  desconocida:  False PROPN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cuk-it.com  alpha: False  stop:  False  desconocida:  True PROPN
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol True
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: Tortillas mexicanas ss word ['Tortillas', 'mexicanas', 'ss'] ::grammar: False
# ::ocr_validate None
# r ‘ - TORTILLAS
#
# MEXICANAS
#
# ee CUKi(’ CuK IT.com
#  49
# r  alpha: True  stop:  False  desconocida:  False CCONJ
#     sem: False syntax: False spanish: True  is_consonant True is_ingredient False is_symbol False
# ::NO es simbolo
# ‘  alpha: False  stop:  False  desconocida:  False SYM
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# -  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# tortillas  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient True is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# mexicanas  alpha: True  stop:  False  desconocida:  False ADJ
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ee  alpha: True  stop:  False  desconocida:  False INTJ
#     sem: False syntax: False spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cuki  alpha: True  stop:  False  desconocida:  True VERB
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# (  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# ’  alpha: False  stop:  False  desconocida:  False NOUN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# cuk  alpha: True  stop:  False  desconocida:  True ADJ
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# it.com  alpha: False  stop:  False  desconocida:  True PROPN
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: Tortillas mexicanas word ['Tortillas', 'mexicanas'] ::grammar: True
# ::ocr_validate Tortillas mexicanas
# Tortillas  -  Tortillas mexicanas
# - : TORTIELAS
#
# MEXICANAS
#
# ~~ CUKit’ —cUK IT.com
#  48
# -  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# :  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# tortielas  alpha: True  stop:  False  desconocida:  True NOUN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# mexicanas  alpha: True  stop:  False  desconocida:  False ADJ
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ~~  alpha: False  stop:  False  desconocida:  False VERB
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# cukit  alpha: True  stop:  False  desconocida:  True NOUN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ’  alpha: False  stop:  False  desconocida:  False SYM
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# —  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# cuk  alpha: True  stop:  False  desconocida:  True ADJ
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# it.com  alpha: False  stop:  False  desconocida:  True PROPN
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: mexicanas word ['mexicanas'] ::grammar: True
# ::ocr_validate mexicanas
# Tortillas mexicanas  -  mexicanas
# > ee ae
#
# ———
# r ‘ cORTIELAS
#
# MEXICANAS
#
# ee CUKit/ ss cuK IT.com
#  63
# >  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# ee  alpha: True  stop:  False  desconocida:  False PROPN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ae  alpha: True  stop:  False  desconocida:  False PROPN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# —  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# —  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# —  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# r  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: False spanish: True  is_consonant True is_ingredient False is_symbol False
# ::NO es simbolo
# ‘  alpha: False  stop:  False  desconocida:  False SYM
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# cortielas  alpha: True  stop:  False  desconocida:  True VERB
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# mexicanas  alpha: True  stop:  False  desconocida:  False ADJ
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ee  alpha: True  stop:  False  desconocida:  False INTJ
#     sem: False syntax: False spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cukit/  alpha: False  stop:  False  desconocida:  True NUM
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ss  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cuk  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# it.com  alpha: False  stop:  False  desconocida:  True NUM
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: ee mexicanas ss word ['ee', 'mexicanas', 'ss'] ::grammar: False
# ::ocr_validate None
# “~~ Le
#
# - - TORTILLAS
#
# MEXICANAS
#
# ee CUKit/ CuK IT.com
#  55
# “  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# ~~  alpha: False  stop:  False  desconocida:  False VERB
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# le  alpha: True  stop:  True  desconocida:  False PRON
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# -  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# -  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# tortillas  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient True is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# mexicanas  alpha: True  stop:  False  desconocida:  False ADJ
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ee  alpha: True  stop:  False  desconocida:  False INTJ
#     sem: False syntax: False spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cukit/  alpha: False  stop:  False  desconocida:  True NUM
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cuk  alpha: True  stop:  False  desconocida:  True ADJ
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# it.com  alpha: False  stop:  False  desconocida:  True NUM
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: Tortillas mexicanas word ['Tortillas', 'mexicanas'] ::grammar: True
# ::ocr_validate Tortillas mexicanas
# Tortillas mexicanas  -  Tortillas mexicanas
# Se  .-
#
# ee
# - -  TORTILEAS
#
# MEXICANAS
#
# ee CUKi(’ CuK IT.com
#  59
# se  alpha: True  stop:  True  desconocida:  False PRON
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#    alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# .-  alpha: False  stop:  False  desconocida:  False NOUN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ee  alpha: True  stop:  False  desconocida:  False INTJ
#     sem: False syntax: False spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# -  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# -  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
#    alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# tortileas  alpha: True  stop:  False  desconocida:  True NOUN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# mexicanas  alpha: True  stop:  False  desconocida:  False ADJ
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ee  alpha: True  stop:  False  desconocida:  False INTJ
#     sem: False syntax: False spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cuki  alpha: True  stop:  False  desconocida:  True VERB
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# (  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# ’  alpha: False  stop:  False  desconocida:  False NOUN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# cuk  alpha: True  stop:  False  desconocida:  True ADJ
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# it.com  alpha: False  stop:  False  desconocida:  True PROPN
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: mexicanas word ['mexicanas'] ::grammar: True
# ::ocr_validate mexicanas
# Tortillas mexicanas  -  mexicanas
# ” | ol a
# | —s
# - - TORTILLAS
#
# MEXICANAS
#
# ee CUKit’ CuK IT.com
#  61
# ”  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# |  alpha: False  stop:  False  desconocida:  False PUNCT
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
# ol  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# a  alpha: True  stop:  True  desconocida:  False ADP
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
# ...
# ::NO es simbolo
# pul  alpha: True  stop:  False  desconocida:  False ADV
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# dd  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# inte  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# resar  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: reciente it pul dd inte word ['reciente', 'it', 'pul', 'dd', 'inte'] ::grammar: False
# ::ocr_validate None
# PO RMAS RECIENTE
#
# CUK it’
#
# SUSCRIRITE
#
# PStOU PUL DD INTE RESAR
#  63
# po  alpha: True  stop:  False  desconocida:  False INTJ
#     sem: False syntax: False spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# rmas  alpha: True  stop:  False  desconocida:  True NOUN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# reciente  alpha: True  stop:  False  desconocida:  False ADJ
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cuk  alpha: True  stop:  False  desconocida:  True NOUN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# it  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ’  alpha: False  stop:  False  desconocida:  False NOUN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# suscririte  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# pstou  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# pul  alpha: True  stop:  False  desconocida:  False ADV
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# dd  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# inte  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# resar  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: reciente it pul dd inte word ['reciente', 'it', 'pul', 'dd', 'inte'] ::grammar: False
# ::ocr_validate None
# PO RMAS RECIENTE
#
# CUK it’
#
# SUSCRIRITE
#
# PStOU PUL DD INTE RESAR
#  63
# po  alpha: True  stop:  False  desconocida:  False INTJ
#     sem: False syntax: False spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# rmas  alpha: True  stop:  False  desconocida:  True NOUN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# reciente  alpha: True  stop:  False  desconocida:  False ADJ
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cuk  alpha: True  stop:  False  desconocida:  True NOUN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# it  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ’  alpha: False  stop:  False  desconocida:  False NOUN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# suscririte  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# pstou  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# pul  alpha: True  stop:  False  desconocida:  False ADV
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# dd  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# inte  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# resar  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: reciente it pul dd inte word ['reciente', 'it', 'pul', 'dd', 'inte'] ::grammar: False
# ::ocr_validate None
# PO RMAS RECIENTE
#
# CUK it’
#
# SUSCRIRITE
#
# PStOU PUL DD INTE RESAR
#  63
# po  alpha: True  stop:  False  desconocida:  False INTJ
#     sem: False syntax: False spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# rmas  alpha: True  stop:  False  desconocida:  True NOUN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# reciente  alpha: True  stop:  False  desconocida:  False ADJ
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cuk  alpha: True  stop:  False  desconocida:  True NOUN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# it  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ’  alpha: False  stop:  False  desconocida:  False NOUN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# suscririte  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# pstou  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# pul  alpha: True  stop:  False  desconocida:  False ADV
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# dd  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# inte  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# resar  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: reciente it pul dd inte word ['reciente', 'it', 'pul', 'dd', 'inte'] ::grammar: False
# ::ocr_validate None
# PO RMAS RECIENTE
#
# CUK it’
#
# SUSCRIRITE
#
# PStOU PUL DD INTE RESAR
#  63
# po  alpha: True  stop:  False  desconocida:  False INTJ
#     sem: False syntax: False spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# rmas  alpha: True  stop:  False  desconocida:  True NOUN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# reciente  alpha: True  stop:  False  desconocida:  False ADJ
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cuk  alpha: True  stop:  False  desconocida:  True NOUN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# it  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ’  alpha: False  stop:  False  desconocida:  False NOUN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# suscririte  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# pstou  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# pul  alpha: True  stop:  False  desconocida:  False ADV
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# dd  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# inte  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# resar  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: reciente it pul dd inte word ['reciente', 'it', 'pul', 'dd', 'inte'] ::grammar: False
# ::ocr_validate None
# PO RMAS RECIENTE
#
# CUK it’
#
# SUSCRIRITE
#
# PStOU PUL DD INTE RESAR
#  63
# po  alpha: True  stop:  False  desconocida:  False INTJ
#     sem: False syntax: False spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# rmas  alpha: True  stop:  False  desconocida:  True NOUN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# reciente  alpha: True  stop:  False  desconocida:  False ADJ
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# cuk  alpha: True  stop:  False  desconocida:  True NOUN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# it  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# ’  alpha: False  stop:  False  desconocida:  False NOUN
#     sem: False syntax: True spanish: True  is_consonant False is_ingredient False is_symbol True
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# suscririte  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# pstou  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# pul  alpha: True  stop:  False  desconocida:  False ADV
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# dd  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# inte  alpha: True  stop:  False  desconocida:  False NOUN
#     sem: True syntax: True spanish: True  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# resar  alpha: True  stop:  False  desconocida:  True PROPN
#     sem: True syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
#
#   alpha: False  stop:  False  desconocida:  True SPACE
#     sem: False syntax: False spanish: False  is_consonant False is_ingredient False is_symbol False
# ::NO es simbolo
# :: reciente it pul dd inte word ['reciente', 'it', 'pul', 'dd', 'inte'] ::grammar: False
# ::ocr_validate None
# anas mexicanas Tortillas Tortillas mexicanas 4 Tortillas Tortillas Tortillas mexicanas Tortillas 4 Tortillas Tortillas 1 Tortillas 4 Agua 150 am 7 1 Agua 150 Agua 150 Agua 150 am Agua 150 2 Agua 150 am Agua 150 Agua 150 am mezclar 3 7 dejar descansar 15 minutos estirar 1 4 41 2 19 4 cocinar 30 segundos lado 30 segundos da lado 30 segundos lado 4 cocinar 30 as 87 ng Tortillas 4 Tortillas mexicanas hablar mexicanas Tortillas 2 Tortillas mexicanas 7

# %%
complete_text
# Out:
# ['anas',
#  'mexicanas',
#  'Tortillas',
#  'Tortillas mexicanas',
#  '4 Tortillas',
#  'Tortillas',
#  'Tortillas mexicanas',
#  'Tortillas',
#  '4 Tortillas',
#  'Tortillas 1',
#  'Tortillas',
#  '4',
#  'Agua 150 am',
#  '7 1 Agua 150',
#  'Agua 150',
#  'Agua 150 am',
#  'Agua 150',
#  '2 Agua 150 am',
#  'Agua 150',
#  'Agua 150 am',
#  'mezclar',
#  '3',
#  '7 dejar descansar 15 minutos',
#  'estirar',
#  '1',
#  '4',
#  '41',
#  '2',
#  '19',
#  '4 cocinar 30 segundos lado',
#  '30 segundos da lado',
#  '30 segundos lado',
#  '4 cocinar 30',
#  'as',
#  '87 ng',
#  'Tortillas 4',
#  'Tortillas mexicanas',
#  'hablar',
#  'mexicanas',
#  'Tortillas',
#  '2 Tortillas mexicanas',
#  '7']

# %%
prev_text
# Out:
# '2 Tortillas mexicanas'

# %%
print(' '.join(complete_text))
# Out:
# anas cu Tortillas mexicanas Tortillas Tortillas mexicanas 4 Tortillas Tortillas Tortillas mexicanas Tortillas 4 Tortillas pe Tortillas 1 Tortillas 4 Agua 150 7 1 Agua 150 Agua 150 am Agua 150 2 Agua 150 Agua 150 Agua 150 am mezclar re 3 cis ea 7 dejar descansar 15 minutos estirar 1 4 41 2 19 4 cocinar 30 segundos lado 30 segundos da lado 30 segundos lado 4 cocinar 30 as Tortillas 4 Tortillas mexicanas hablar mexicanas Tortillas 2 Tortillas mexicanas

# %%
def word_validate2(sentence):
    doc_es = nlp(sentence)
    words =  []

    # Expresión regular que busca cualquier caracter que no sea una letra, número o espacio en blanco
    patron = r'[^a-zA-Z1-9ñÑáéíóúÁÉÍÓÚüÜ\d\s/\d.]'
    validate = ['NUM', 'PUNCT']

    is_valid = []
    have_ingredient = False

    for token in doc_es:

        # Buscamos el patrón en el texto
        res = re.search(patron, token.text)

        # Si se encuentra algún símbolo devuelve True
        is_symbol = res is not None


        print(token.i, token.text, " alpha:", token.is_alpha, " stop: " , token.is_stop, " desconocida: ", token.is_oov, "token.tag_", token.tag_ , "token.pos_", token.pos_, "token.dep_", token.dep_)
        print("    sem:", token._.is_semantic,  "syntax:", token._.is_syntax, "spanish:", token._.is_spanish, " is_consonant", token._.is_consonant, "is_ingredient", token._.is_ingredient, "is_symbol", is_symbol )


        if not is_symbol:
            print("::NO es simbolo")
            if token.text == '/':
                continue
            if token._.is_ingredient:
                have_ingredient = True
                words.append(token.text.capitalize())
                is_valid.append(True)
                continue

            #if token.tag_ not in validate:

                #is_spanish = spanish_word(token)
                #is_valid = all([token._.is_semantic, token._.is_spanish, token._.is_syntax])

                #if is_valid :
                #    words.append(token.text)
            #else:
            #    words.append(token.text)

            if all([token._.is_semantic, token._.is_spanish, token._.is_syntax]):
                words.append(token.text)
                is_valid.append(True)
                continue
        # else:
        #     is_valid.append(False)


    # if have_ingredient : 

    #     print("::" , sentence, "word",  words )
    #     return ' '.join(words)
    
    
    # if all([valid for valid in is_valid]):
    #     return ' '.join(words)
    # else:
    #     return None

        #print("La oración es inválida.")
    
    sentence = ' '.join(words)
    grammar  = grammar_validate(sentence)
    print("::grammar:", grammar, words)
    
    if not grammar:
        return None
    return sentence

# %%
ocr_validate = word_validate2(',')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ocr_validate = word_validate2(',')
#
# Cell In[2], line 2, in word_validate2(sentence)
#       1 def word_validate2(sentence):
# ----> 2     doc_es = nlp(sentence)
#       3     words =  []
#       5     # Expresión regular que busca cualquier caracter que no sea una letra, número o espacio en blanco
#
# NameError: name 'nlp' is not defined

# %%
nlp.vocab.has_vector("Tatemar")
# Out:
# False

# %%
grammar_validate('Tatemar')
# Out:
# False

# %%
'mexicanas',
 'Tortillas',
 'Tortillas mexicanas',
 '4 Tortillas',
# Out:
#   Cell In[178], line 2
#     'Tortillas',
#     ^
# IndentationError: unexpected indent

# %%
# Obtener el objeto Doc para cada texto:
pt = nlp('Tortillas mexicanas')
nt = nlp('4 Tortillas')

# Calcular la similitud entre los textos:
pt.similarity(nt)
# Out:
# 0.15011704153336758

# %%
def add_punct(token):
    if
