# %%
pip install SpeechRecognition moviepy  pafy pattern3  pydub --upgrade youtube_dl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: SpeechRecognition in /Users/jasura/Library/Python/3.9/lib/python/site-packages (3.10.0)
# Requirement already satisfied: moviepy in /Users/jasura/Library/Python/3.9/lib/python/site-packages (1.0.3)
# Requirement already satisfied: pafy in /Users/jasura/Library/Python/3.9/lib/python/site-packages (0.5.5)
# Requirement already satisfied: pattern3 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (3.0.0)
# Requirement already satisfied: pydub in /Users/jasura/Library/Python/3.9/lib/python/site-packages (0.25.1)
# Requirement already satisfied: youtube_dl in /Users/jasura/Library/Python/3.9/lib/python/site-packages (2021.12.17)
# Requirement already satisfied: requests>=2.26.0 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from SpeechRecognition) (2.28.2)
# Requirement already satisfied: proglog<=1.0.0 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from moviepy) (0.1.10)
# Requirement already satisfied: imageio<3.0,>=2.5 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from moviepy) (2.27.0)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from moviepy) (4.65.0)
# Requirement already satisfied: numpy>=1.17.3 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from moviepy) (1.24.2)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from moviepy) (0.4.8)
# Requirement already satisfied: cherrypy in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pattern3) (18.8.0)
# Requirement already satisfied: pdfminer.six in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pattern3) (20221105)
# Requirement already satisfied: simplejson in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pattern3) (3.19.1)
# Requirement already satisfied: docx in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pattern3) (0.2.4)
# Requirement already satisfied: feedparser in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pattern3) (6.0.10)
# Requirement already satisfied: beautifulsoup4 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pattern3) (4.12.2)
# Requirement already satisfied: pdfminer3k in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pattern3) (1.3.4)
# Requirement already satisfied: pillow>=8.3.2 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from imageio<3.0,>=2.5->moviepy) (9.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from requests>=2.26.0->SpeechRecognition) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from requests>=2.26.0->SpeechRecognition) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from requests>=2.26.0->SpeechRecognition) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from requests>=2.26.0->SpeechRecognition) (2022.12.7)
# Requirement already satisfied: soupsieve>1.2 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from beautifulsoup4->pattern3) (2.4)
# Requirement already satisfied: more-itertools in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from cherrypy->pattern3) (9.1.0)
# Requirement already satisfied: zc.lockfile in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from cherrypy->pattern3) (3.0.post1)
# Requirement already satisfied: cheroot>=8.2.1 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from cherrypy->pattern3) (9.0.0)
# Requirement already satisfied: jaraco.collections in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from cherrypy->pattern3) (4.1.0)
# Requirement already satisfied: portend>=2.1.1 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from cherrypy->pattern3) (3.1.0)
# Requirement already satisfied: lxml in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from docx->pattern3) (4.9.2)
# Requirement already satisfied: sgmllib3k in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from feedparser->pattern3) (1.0.0)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pdfminer.six->pattern3) (39.0.2)
# Requirement already satisfied: ply in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pdfminer3k->pattern3) (3.11)
# Requirement already satisfied: jaraco.functools in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from cheroot>=8.2.1->cherrypy->pattern3) (3.6.0)
# Requirement already satisfied: six>=1.11.0 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from cheroot>=8.2.1->cherrypy->pattern3) (1.15.0)
# Requirement already satisfied: cffi>=1.12 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from cryptography>=36.0.0->pdfminer.six->pattern3) (1.15.1)
# Requirement already satisfied: tempora>=1.8 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from portend>=2.1.1->cherrypy->pattern3) (5.2.2)
# Requirement already satisfied: jaraco.text in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from jaraco.collections->cherrypy->pattern3) (3.11.1)
# Requirement already satisfied: setuptools in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from zc.lockfile->cherrypy->pattern3) (67.6.1)
# Requirement already satisfied: pycparser in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->pattern3) (2.21)
# Requirement already satisfied: pytz in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->pattern3) (2022.7.1)
# Requirement already satisfied: autocommand in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from jaraco.text->jaraco.collections->cherrypy->pattern3) (2.2.2)
# Requirement already satisfied: inflect in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from jaraco.text->jaraco.collections->cherrypy->pattern3) (6.0.4)
# Requirement already satisfied: jaraco.context>=4.1 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from jaraco.text->jaraco.collections->cherrypy->pattern3) (4.3.0)
# Requirement already satisfied: pydantic>=1.9.1 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from inflect->jaraco.text->jaraco.collections->cherrypy->pattern3) (1.10.7)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/jasura/Library/Python/3.9/lib/python/site-packages (from pydantic>=1.9.1->inflect->jaraco.text->jaraco.collections->cherrypy->pattern3) (4.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install SpeechRecognition moviepy
#pip install pafy
#pip install --upgrade youtube_dl

# Reconocimiento de Audio
import speech_recognition as sr
import moviepy.editor as mp

# Manipulación de Audio 
from pydub import AudioSegment
from pydub.silence import split_on_silence
from pytube import YouTube

# Otras librerías
import os, shutil
import json

# %%
class SoundToText:
    """
    Define un archivo con formato de video.
    """
    def __init__(self, video_file):
        self.video_file = video_file
        self.current_directory = os.getcwd()
        self.video_description = ""
        self.current_folder = self.current_directory + "/Converted_results"
        self.converted_audio = self.current_folder + "/"+ "Converted_audio.wav"
    
    """
    Convierto un video a audio. 
    """
    def convert_video_to_audio(self):
        if "youtube" in self.video_file: #optimizar en frontend
            self.download_from_youtube()
            self.convert_to_audio()
            self.read_audio_file()
            self.get_audio_transcription()
        else:
            self.read_audio_file()
            self.get_audio_transcription()
        #self.remove_filed() #TODO error => no elimina mp4
        
    """
    Descarga un video de YouTube.
    """
    def download_from_youtube(self):
        yt_file = YouTube(self.video_file)
        self.video_description = yt_file.description
        
        yt_file = yt_file.streams.get_highest_resolution()
        if not os.path.exists(self.current_folder):
            os.makedirs(self.current_folder)
        yt_file.download(self.current_folder)
      #  yt_file.close()
     
    """
    Convierte un video a audio.
    """
    def convert_to_audio(self):
        for file in os.listdir(self.current_folder):
            file = self.current_folder + "/" + file
            if file.endswith(".mp4"):
                raw_string = r"{}".format(file)
                raw_audio = r"{}".format( self.converted_audio)
                
                clip = mp.VideoFileClip(raw_string)
                clip.audio.write_audiofile(raw_audio)
                print("Conversión a audio ha sido finalizada...")
                   
    """ 
    Lee el video de audio. 
    """
    def read_audio_file(self):
        audio = sr.AudioFile(self.converted_audio)
        print("Audio ha sido leído...")
     
    """
    Define una función para normalizar un fragmento a una amplitud dada.
    """
    def match_target_amplitude(self, audio_chunk, target_dBFS):
        change_in_dBFS = target_dBFS - audio_chunk.dBFS
        return audio_chunk.apply_gain(change_in_dBFS)

    """
    Divide archivo de audio en fragmentos.
    """
    def create_audio_chunks(self, audio):
        chunks = split_on_silence(audio,
            min_silence_len = 500,
            silence_thresh = -40,
        )
        return chunks

    """
    Se obtiene la transcripción del audio.
    """
    def get_audio_transcription(self):
        r = sr.Recognizer()
        
        # Se aplica speech recognition
        path = self.converted_audio
        
        # Abre el archivo de audio
        folder_name = path.replace("wav","")
    
        # Crea el archivo de texto.
        fh = open(folder_name + "txt", "w+") 
        audio = AudioSegment.from_wav(path)  
    
        # Divide el audio en fragmentos.
        chunks = self.create_audio_chunks(audio)
    
        # Crea un directorio para almacenar los fragmentos de audio
        if not os.path.isdir(folder_name):
            os.mkdir(folder_name)
        whole_text = ""

        # Procesa cada fragmento.
        for i, audio_chunk in enumerate(chunks, start=0):
            silence_chunk = AudioSegment.silent(duration=500)
            
            # Agrega un padding al inicio y al final de todo el fragmento.
            audio_chunk = silence_chunk + audio_chunk + silence_chunk
            
            # Exporta fragmento de audio y se guarda en el directorio. 
            chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
            
            # Normaliza el fragmento completo.
            normalized_chunk = self.match_target_amplitude(audio_chunk, -20.0)
            
            normalized_chunk.export(chunk_filename, bitrate = "192k", format="wav")
            
            # Se preprocesa el fragmento.
            with sr.AudioFile(chunk_filename) as source:
                r.energy_threshold = 400
                r.adjust_for_ambient_noise(source, duration=0.5)
                
                audio_file = r.record(source)
            
                try:  
                    text = r.recognize_google(audio_file, language='es-MX') 
                except sr.UnknownValueError as e:
                    print("Error:", str(e))
                else:
                    text = f"{text} "
                    whole_text += text
                    
        # Si existe una descripción, se agregará en el archivo de texto.
        video_description = "\nDescripción del Video: \n" + str(self.video_description)
        whole_text += video_description
        
        #word = "ingredientes" # TODO cambiar palabras 
        #if not word in whole_text:
        #    print("No es video-receta!")
        #    return
        
        # Guarda el texto completo del video.
        fh.write(whole_text + "\n") 
        fh.close() 
        return print("\nFull text:", whole_text)
    
    """
    Elimina todos los archivos de la carpeta creada al finalizar el procesamiento.
    El archivo de texto se guarda en la nube. #TODO
    """
    def remove_filed(self):
        for filename in os.listdir(self.current_folder):
            file_path = os.path.join(self.current_folder, filename)
            try:
                if os.path.isfile(file_path) or os.path.islink(file_path):
                    os.unlink(file_path)
                elif os.path.isdir(file_path):
                    shutil.rmtree(file_path)
            except Exception as e:
                print('Failed to delete %s. Reason: %s' % (file_path, e))

# %%
videourl = "https://www.youtube.com/watch?v=eQpAi5CogiQ"  #"https://www.youtube.com/watch?v=TzbvfPaGHl4" #(rajas) # "https://www.youtube.com/watch?v=eQpAi5CogiQ" (chiles) #https://www.youtube.com/watch?v=TzbvfPaGHl4 (con ingredientes)"  #"https://www.youtube.com/watch?v=qi3V_ArpDp4" 
to_text = SoundToText(videourl)

# %%
to_text.current_folder
# Out:
# '/Users/jasura/Documents/maestria/seminario/javan-vrc/backend/Converted_results'

# %%
to_text.convert_video_to_audio()
# Out:
# MoviePy - Writing audio in /Users/jasura/Documents/maestria/seminario/javan-vrc/backend/Converted_results/Converted_audio.wav
# MoviePy - Done.
# Conversión a audio ha sido finalizada...
# Audio ha sido leído...
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
# Error:
#
# Full text: Hola mi gente Bienvenidos a mi rancho Hoy les voy a hacer unos sabrosos chiles rellenos sin capear los voy a hacer con crema y van a ver que se van a quedar bien sabrosos Aquí tengo 10 chiles poblanos unos traguitos de queso tomates una torta de cebolla y un diente de ajo cuatro chiles guajillos poquita crema y ahorita voy a preparar van a ver que me van a quedar bien Buenos bien sabrosos primero voy a poner a hacer los chiles en Mientras voy a desvenar estos chilitos guajillos para ponerlos a cocer voy a poner a cocer los chilitos les voy a poner unas pimienta negra Y también voy a asar Mira de que se cosen los chiles voy a basar estos jitomates tus enlazados y la cebolla también vasada y el ajo Ya los voy a quitar que ya estuvieron ya los chili ya está me voy poniendo aquí a la bolsita para que se sude un poquito y se les pueda quitar la tecatita Yo también ya están los chiles voy a ir pelando ahora voy a desvelar ya tengo aquí todos limpios los voy a desvenar Yo los tengo aquí para en pedacitos Mira así para que se rellenen Ya los tengo aquí todos limpios ahora lo voy a rellenar aquí yo lo voy a rellenar de queso pero también se pueden llenar de picadillo también se rellenan de atún de los que ustedes quieran rellenarlos Sí también quedan bien sabrosos yo tengo aquí la casa de la calentando la voy a poner poquito de aceite y en lo que se calienta voy a moler el chile el jitomate voy a poner los jitomates la cebolla y el ajo y acá están los chilitos con la pimienta le voy a poner la crema te voy a poner poquita agua me voy a poner poquita sal te voy a moler ya que está caliente el aceite le voy a poner una rebanadita de cebolla te lo voy a poner aquí tomate aquí lo voy a dejar que hierva bien hervido para agregarle los chiles ya está hirviendo la crema le voy a poner aquí los chiles ya no más los voy a dejar que llueva un poquito para que los chiles agarren el sabor de la cremita y los del quesito este suavecito ya estuvieron mire qué sabroso se ven Ahora me voy a servir para probar a ver qué tal me quedaron yo los voy a acompañar con arrocito rojo que dice mi hija Brenda voy a dejar que se enfríe un poquito porque está bien caliente ahora voy a probar qué tal me quedaron me quedaron bien sabrosos Así que a mí me gustan háganos y verán que les va a gustar yo los preparé con mucho gusto de mi rancho a su cocina
# Descripción del Video:
# None
